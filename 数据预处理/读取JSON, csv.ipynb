# %%
import pandas as pd

# %% [markdown]
# **JSON: javascript object notion**

# %%
survey_df = pd.read_json("./cell_phones_survey.json")  # 自动转为DataFrame
survey_df
# Out:
#   questionType        asin    answerTime    unixTime  \
# 0       yes/no  1466736038   Mar 8, 2014  1394265600
# 1       yes/no  1466736038  Jan 29, 2015  1422518400
# 2       yes/no  1466736038  Nov 30, 2014  1417334400
# 3   open-ended  1466736038   Nov 3, 2014  1415001600
# 4       yes/no  1466736038   Oct 2, 2014  1412233200
# 5   open-ended  1466736038  Sep 11, 2014  1410418800
# 6       yes/no  1621911888  Dec 13, 2013  1386921600
#
#                                             question answerType  \
# 0                         Is there a SIM card in it?          Y
# 1  Is this phone new, with 1 year manufacture war...          ?
# 2  can in it be used abroad with a different carr...          Y
# 3                      What is the warranty on this?        NaN
# 4  Does this phone use the regular Sim card (the ...          ?
# 5  how much time you need to send me this product...        NaN
# 6                                    Is it unlocked?          Y
#
# ...

# %%
github_df = pd.read_json("./github.json")
github_df
# Out:
#      owner           name  stars  forks  watchers  isFork  \
# 0  pelmers  text-rewriter     11      4         3   False
# 1  pelmers  text-rewriter     11      4         3   False
# 2  pelmers  text-rewriter     11      4         3   False
#
#                                languages  \
# 0  {'name': 'JavaScript', 'size': 21769}
# 1         {'name': 'HTML', 'size': 2096}
# 2          {'name': 'CSS', 'size': 2081}
#
#                                 description             createdAt  \
# 0  Webextension to rewrite phrases in pages  2015-03-14T22:35:11Z
# 1  Webextension to rewrite phrases in pages  2015-03-14T22:35:11Z
# 2  Webextension to rewrite phrases in pages  2015-03-14T22:35:11Z
#
#                pushedAt  license
# 0  2022-02-11T14:26:00Z      NaN
# 1  2022-02-11T14:26:00Z      NaN
# 2  2022-02-11T14:26:00Z      NaN

# %% [markdown]
# **csv: Comma-Seperated Values**

# %%
import pandas as pd

# %%
fifa_df = pd.read_csv("./fifa_players.csv")
fifa_df
# Out:
# /Users/mac/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (108) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         player_id                                        player_url  \
# 0          158023                /player/158023/lionel-messi/150002
# 1           20801  /player/20801/c-ronaldo-dos-santos-aveiro/150002
# 2            9014                  /player/9014/arjen-robben/150002
# 3           41236           /player/41236/zlatan-ibrahimovic/150002
# 4          167495                /player/167495/manuel-neuer/150002
# ...           ...                                               ...
# 161578     269011                   /player/269011/ziye-zhao/230002
# 161579     269019                   /player/269019/junjie-wu/230002
# 161580     271093               /player/271093/kailin-barlow/230002
# ...

# %% [markdown]
# **把某一列作为标签索引**

# %%
fifa_df1 = pd.read_csv("./fifa_players.csv", index_col="player_id")
fifa_df1  # 默认展示二十列，10行
# Out:
#                                                  player_url  fifa_version  \
# player_id
# 158023                   /player/158023/lionel-messi/150002            15
# 20801      /player/20801/c-ronaldo-dos-santos-aveiro/150002            15
# 9014                       /player/9014/arjen-robben/150002            15
# 41236               /player/41236/zlatan-ibrahimovic/150002            15
# 167495                   /player/167495/manuel-neuer/150002            15
# ...                                                     ...           ...
# 269011                      /player/269011/ziye-zhao/230002            23
# 269019                      /player/269019/junjie-wu/230002            23
# 271093                  /player/271093/kailin-barlow/230002            23
# 271555                  /player/271555/gideon-tetteh/230002            23
# 271608              /player/271608/aqeel-al-dhafeeri/230002            23
#
#            fifa_update fifa_update_date         short_name  \
# ...

# %% [markdown]
# **提升想展示的列**

# %%
pd.set_option("display.max_columns", 150)
fifa_df1
# Out:
#                                                  player_url  fifa_version  \
# player_id
# 158023                   /player/158023/lionel-messi/150002            15
# 20801      /player/20801/c-ronaldo-dos-santos-aveiro/150002            15
# 9014                       /player/9014/arjen-robben/150002            15
# 41236               /player/41236/zlatan-ibrahimovic/150002            15
# 167495                   /player/167495/manuel-neuer/150002            15
# ...                                                     ...           ...
# 269011                      /player/269011/ziye-zhao/230002            23
# 269019                      /player/269019/junjie-wu/230002            23
# 271093                  /player/271093/kailin-barlow/230002            23
# 271555                  /player/271555/gideon-tetteh/230002            23
# 271608              /player/271608/aqeel-al-dhafeeri/230002            23
#
#            fifa_update fifa_update_date         short_name  \
# ...

# %% [markdown]
# **有些信息没有展示全，有省略号，怎么展示全呢？**

# %%
pd.set_option("display.max_colwidth", 200)
fifa_df1
# Out:
#                                                  player_url  fifa_version  \
# player_id
# 158023                   /player/158023/lionel-messi/150002            15
# 20801      /player/20801/c-ronaldo-dos-santos-aveiro/150002            15
# 9014                       /player/9014/arjen-robben/150002            15
# 41236               /player/41236/zlatan-ibrahimovic/150002            15
# 167495                   /player/167495/manuel-neuer/150002            15
# ...                                                     ...           ...
# 269011                      /player/269011/ziye-zhao/230002            23
# 269019                      /player/269019/junjie-wu/230002            23
# 271093                  /player/271093/kailin-barlow/230002            23
# 271555                  /player/271555/gideon-tetteh/230002            23
# 271608              /player/271608/aqeel-al-dhafeeri/230002            23
#
#            fifa_update fifa_update_date         short_name  \
# ...

# %%
fifa_df.head(2)
# Out:
#    player_id                                        player_url  fifa_version  \
# 0     158023                /player/158023/lionel-messi/150002            15
# 1      20801  /player/20801/c-ronaldo-dos-santos-aveiro/150002            15
#
#    fifa_update fifa_update_date         short_name  \
# 0            2       2014-09-18           L. Messi
# 1            2       2014-09-18  Cristiano Ronaldo
#
#                              long_name player_positions  overall  potential  \
# 0       Lionel Andrés Messi Cuccittini               CF       93         95
# 1  Cristiano Ronaldo dos Santos Aveiro           LW, LM       92         92
#
#      value_eur  wage_eur  age         dob  height_cm  weight_kg  league_id  \
# 0  100500000.0  550000.0   27  1987-06-24        169         67       53.0
# 1   79000000.0  375000.0   29  1985-02-05        185         80       53.0
#
#   league_name  league_level  club_team_id       club_name club_position  \
# ...

# %%
fifa_df.tail()  # 默认五行
# Out:
#         player_id                               player_url  fifa_version  \
# 161578     269011          /player/269011/ziye-zhao/230002            23
# 161579     269019          /player/269019/junjie-wu/230002            23
# 161580     271093      /player/271093/kailin-barlow/230002            23
# 161581     271555      /player/271555/gideon-tetteh/230002            23
# 161582     271608  /player/271608/aqeel-al-dhafeeri/230002            23
#
#         fifa_update fifa_update_date      short_name          long_name  \
# 161578            2       2022-09-26       Zhao Ziye                赵梓业
# 161579            2       2022-09-26       Wu Junjie                吴俊杰
# 161580            2       2022-09-26       K. Barlow      Kailin Barlow
# 161581            2       2022-09-26       G. Tetteh      Gideon Tetteh
# 161582            2       2022-09-26  A. Al Dhafeeri  Aqeel Al Dhafeeri
#
#        player_positions  overall  potential  value_eur  wage_eur  age  \
# ...

# %%
fifa_df.info()  # 数据太多而不会展示太多信息
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161583 entries, 0 to 161582
# Columns: 110 entries, player_id to player_face_url
# dtypes: float64(18), int64(45), object(47)
# memory usage: 135.6+ MB

# %%
amazon_df = pd.read_csv("./amazon.csv")
amazon_df
# Out:
#       product_id  \
# 0     B07JW9H4J1
# 1     B098NS6PVG
# 2     B096MSW6CT
# 3     B08HDJ86NZ
# 4     B08CF3B7N1
# ...          ...
# 1460  B08L7J3T31
# 1461  B01M6453MB
# 1462  B009P2LIL4
# 1463  B00J5DYCCA
# 1464  B01486F4G6
#
#                                                                                                                                                                                                  product_name  \
# 0                                          Wayona Nylon Braided USB to Lightning Fast Charging and Data Sync Cable Compatible for iPhone 13, 12,11, X, 8, 7, 6, 5, iPad Air, Pro, Mini (3 FT Pack of 1, Grey)
# 1           Ambrane Unbreakable 60W / 3A Fast Charging 1.5m Braided Type C Cable for Smartphones, Tablets, Laptops & other Type C devices, PD Technology, 480Mbps Data Sync, Quick Charge 3.0 (RCT15A, Black)
# ...

# %%
amazon_df.info()  # 数据比较少时会展示出更多信息
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
amazon_df.describe()  # 只会展示数字类型的列
# Out:
#         product_id  \
# count         1465
# unique        1351
# top     B07JW9H4J1
# freq             3
#
#                                                                                                                                                      product_name  \
# count                                                                                                                                                        1465
# unique                                                                                                                                                       1337
# top     Fire-Boltt Ninja Call Pro Plus 1.83" Smart Watch with Bluetooth Calling, AI Voice Assistance, 100 Sports Modes IP67 Rating, 240*280 Pixel High Resolution
# freq                                                                                                                                                            5
#
# ...

# %%
amazon_df["rating"]
# Out:
# 0       4.2
# 1       4.0
# 2       3.9
# 3       4.2
# 4       4.2
#        ...
# 1460      4
# 1461    4.1
# 1462    3.6
# 1463      4
# 1464    4.3
# Name: rating, Length: 1465, dtype: object

# %%
fifa_df.describe()
# Out:
#            player_id   fifa_version  fifa_update        overall  \
# count  161583.000000  161583.000000     161583.0  161583.000000
# mean   214484.722353      19.125514          2.0      65.699071
# std     34928.608856       2.559318          0.0       7.040855
# min         2.000000      15.000000          2.0      40.000000
# 25%    199159.000000      17.000000          2.0      61.000000
# 50%    220621.000000      19.000000          2.0      66.000000
# 75%    236958.000000      21.000000          2.0      70.000000
# max    271817.000000      23.000000          2.0      94.000000
#
#            potential     value_eur       wage_eur            age  \
# count  161583.000000  1.595300e+05  159822.000000  161583.000000
# mean       70.744008  2.326770e+06   10855.409768      25.123181
# std         6.259121  6.005746e+06   21941.656285       4.670207
# min        40.000000  1.000000e+03     500.000000      16.000000
# ...

# %%
fifa_df.sample(7)  # 随机选取行，括号里面为行数
# Out:
#         player_id                                      player_url  \
# 13714       11793               /player/11793/steve-collis/150002
# 133917     215277              /player/215277/lee-ashcroft/220002
# 114377     254072       /player/254072/rafael-barros-silva/210002
# 18684      202547  /player/202547/jean-christophe-bahebeck/160002
# 118407     244835             /player/244835/antonio-lopez/210002
# 11080      172145               /player/172145/john-owoeri/150002
# 119374     254456             /player/254456/ronal-huaccha/210002
#
#         fifa_version  fifa_update fifa_update_date     short_name  \
# 13714             15            2       2014-09-18      S. Collis
# 133917            22            2       2021-09-23    L. Ashcroft
# 114377            21            2       2020-09-23  Rafael Barros
# 18684             16            2       2015-09-21    J. Bahebeck
# 118407            21            2       2020-09-23       A. López
# ...
